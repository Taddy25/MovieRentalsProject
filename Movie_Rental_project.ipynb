# %% [markdown]
# <a href="https://colab.research.google.com/github/Taddy25/MovieRentalsProject/blob/main/Movie_Rental_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Mount my Google Drive so I can access files stored there
from google.colab import drive
drive.mount('/content/drive')

import os
import sqlite3

# Step 2: Define the exact path to my database file in Colab
db_path = '/content/movie rental.db'  # <-- Using the path you gave me

# Step 3: Check if my database file exists at this path
if not os.path.exists(db_path):
    print("Database file not found — I’m creating and populating it now...")

    # Step 4: Connect to a new SQLite DB file (this will create it)
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    # Step 5: Create tables and insert initial data in one go
    cursor.executescript("""
    CREATE TABLE customers (
        id INTEGER PRIMARY KEY,
        name TEXT NOT NULL,
        email TEXT NOT NULL
    );

    CREATE TABLE movies (
        id INTEGER PRIMARY KEY,
        title TEXT NOT NULL,
        genre TEXT NOT NULL
    );

    CREATE TABLE rentals (
        id INTEGER PRIMARY KEY,
        customer_id INTEGER,
        movie_id INTEGER,
        rental_date TEXT,
        due_date TEXT,
        return_date TEXT,
        FOREIGN KEY (customer_id) REFERENCES customers(id),
        FOREIGN KEY (movie_id) REFERENCES movies(id)
    );

    INSERT INTO customers (id, name, email) VALUES
    (1, 'Alice Smith', 'alice@example.com'),
    (2, 'Dave Jones', 'dave@example.com'),
    (3, 'Liam Williams', 'liam@example.com'),
    (4, 'Taddy Muroyiwa', 'taddy@example.com'),
    (5, 'Steven Spielberg', 'steven@example.com');

    INSERT INTO movies (id, title, genre) VALUES
    (1, 'Inception', 'Sci-Fi'),
    (2, 'The Godfather', 'Crime'),
    (3, 'Toy Story', 'Animation'),
    (4, 'Forrest Gump', 'Drama'),
    (5, 'The Dark Knight', 'Action');

    INSERT INTO rentals (customer_id, movie_id, rental_date, due_date, return_date) VALUES
    (1, 1, '2025-07-01', '2025-07-08', '2025-07-07'),
    (2, 2, '2025-07-02', '2025-07-09', '2025-07-11'),
    (3, 3, '2025-07-03', '2025-07-10', NULL),
    (4, 4, '2025-07-04', '2025-07-11', NULL),
    (5, 5, '2025-07-05', '2025-07-12', NULL);
    """)

    # Step 6: Save changes and close the cursor
    conn.commit()
    cursor.close()
    print("Database created and populated successfully!")
else:
    # Step 7: If the file exists, just connect to it
    print("Database file found — I’m just connecting to it.")
    conn = sqlite3.connect(db_path)

# Now I can run SQL queries on 'conn' without re-uploading or recreating the DB every time
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Database file found — I’m just connecting to it.
#       customer_name               email      movie_title rental_date  \
# 0        Dave Jones    dave@example.com    The Godfather  2025-07-02
# 1     Liam Williams    liam@example.com        Toy Story  2025-07-03
# 2    Taddy Muroyiwa   taddy@example.com     Forrest Gump  2025-07-04
# 3  Steven Spielberg  steven@example.com  The Dark Knight  2025-07-05
#
#      due_date return_date  return_status  days_late
# 0  2025-07-09  2025-07-11  Returned late          2
# 1  2025-07-10        None   Not returned         11
# 2  2025-07-11        None   Not returned         10
# 3  2025-07-12        None   Not returned          9
